# %% [markdown]
# ## Part 1: Working with Variables, Input, and Strings
#
# ## 1 Prompt for user input
#
# Ask the user to enter their full name and store it in a variable named full_name.
#
# Print a greeting message, for example:
#
# Hello, ! Welcome to the Python assignment.

# %%
full_name = input("Enter your full name : ")
print(full_name)
# Out:
# Enter your full name :  Mudasser ALi
# Mudasser ALi

# %% [markdown]
# ## 2 String methods
# Print the user’s name in all uppercase letters.
#
# Print the user’s name in all lowercase letters.
#
# Print the length of the user’s name (number of characters).
#
# Replace all the spaces in the user’s name with hyphens (-), and print the result.
#
# Bonus: Trim any leading or trailing spaces (if any) from the user’s name using strip().

# %%
# Print the user’s name in all uppercase letters.
print(full_name.upper())
# Print the user’s name in all lowercase letters.
print(full_name.lower())
# Print the length of the user’s name (number of characters).
print(len(full_name))
# Replace all the spaces in the user’s name with hyphens (-), and print the result.
space_replace = full_name.replace(" ","-")
print(space_replace)

print(full_name.strip())
# Out:
# MUDASSER ALI
# mudasser ali
# 12
# Mudasser-ALi
# Mudasser ALi

# %% [markdown]
# ## 3 Type casting and numeric operations
# Ask the user to enter their birth year (as input). Convert that input to an integer.
#
# Calculate the user’s approximate age by subtracting the birth year from the current year. Print the result in a sentence.
#
# Example output:
#
# You are approximately 25 years old.

# %%
birth_year = input("Enter your birth year: ")
age = int(birth_year)
current_year = 2026
approximate_age = current_year - age
print(f"You are approximately {approximate_age} years old.")
# Out:
# Enter your age:  2003
# You are approximately 23 years old.

# %% [markdown]
# ## Part 2: Lists and Indexing
# ### 1-Create a list from user input
#
# Prompt the user to enter three of their favorite fruits (e.g., "apple,banana,orange") in one line, separated by commas.
#
# Split the string by commas to create a list called fruit_list.
#
# Print the list to verify that it’s correct.

# %%
favorite_fruits = input("Enter three of your favorite fruits (comma-separated): ").split(",")
fruit_list = list(favorite_fruits)
print(fruit_list)
# Out:
# Enter three of your favorite fruits (comma-separated):  mango,apple,orange
# ['mango', 'apple', 'orange']

# %% [markdown]
# ## 2-List indexing and slicing
#
# Print the first fruit in the list.
#
# Print the last fruit in the list.
#
# Print the second fruit in the list using indexing (i.e., fruit_list[1]).
#
# Print the slice of the list containing the first two fruits.

# %%
# Print the first fruit in the list.
print("The first fruit in the list : ",fruit_list[0])

#Print the last fruit in the list.
print("The last fruit in the list : ",fruit_list[-1])

# Print the second fruit in the list using indexing (i.e., fruit_list[1]).
print("The second fruit in the list : " , fruit_list[1])

# Print the slice of the list containing the first two fruits.
slice_list = fruit_list[0:2]
print("The slice of the list containing the first two fruits : ",slice_list)
# Out:
# The first fruit in the list :  mango
# The last fruit in the list :  orange
# The second fruit in the list :  apple
# The slice of the list containing the first two fruits :  ['mango', 'apple']

# %% [markdown]
# ### 3-List methods
#
# Append a new fruit to the list using append(). Print the updated list.
#
# Remove one fruit from the list using remove() (or pop()). Print the updated list again.
#
# Print the length of the list using len().

# %%
# Append a new fruit to the list using append(). Print the updated list.
updated_fruit_list = fruit_list.append('banana')
#print("New list : ",updated_fruit_list)  return none
print("New list : ",fruit_list)

# Remove one fruit from the list using remove() (or pop()). Print the updated list again.

fruit_list.remove('apple')   
print("After remove:", fruit_list)

# Print the length of the list using len().
print(len(fruit_list))
# Out:
# New list :  ['mango', 'orange', 'banana', 'banana', 'banana', 'banana']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 8
#       4 print("New list : ",fruit_list)
#       6 # Remove one fruit from the list using remove() (or pop()). Print the updated list again.
# ----> 8 fruit_list.remove('apple')
#       9 print("After remove:", fruit_list)
#      11 # Print the length of the list using len().
#
# ValueError: list.remove(x): x not in list
